# %%
from brainlit.utils.ngl_pipeline import NeuroglancerSession
from brainlit.preprocessing.features import *
from brainlit.preprocessing import gabor_filter
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from scipy import interp
from scipy import mean
from sklearn import preprocessing
from scipy.stats import sem, t
import matplotlib.pyplot as plt

# %%
nbr = NeighborhoodFeatures(url="s3://mouse-light-viz/precomputed_volumes/brain1", size=[5,5,5], offset=[15,15,15])
df_nbr = nbr.fit(seg_ids=[2], num_verts=1000)
# Out:
# ng:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 35.17it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.00it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.46it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 37.41it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 35.28it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 35.86it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 16.80it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 34.90it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 36.79it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 35.56it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.59it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 23.58it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 33.43it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.13it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.30it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 38.12it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.57it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.64it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.72it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 18.42it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.57it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.70it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.47it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.52it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.13it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 19.25it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.20it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 33.80it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 33.50it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 17.77it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.81it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.24it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 23.86it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.63it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.39it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.15it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.22it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 36.12it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.82it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 15.25it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.25it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 35.08it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 15.55it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.04it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.38it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:01<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.83it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.28it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 34.67it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.43it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.49it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.99it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 34.14it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 13.70it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 11.08it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 13.74it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 21.46it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 33.17it/s]
# Downloading:   0%|          | 0/1 [00:01<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.62it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.24it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.51it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 30.39it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.95it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 28.00it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.40it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 24.44it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.93it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  7.47it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 32.05it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 25.53it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 18.36it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.85it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 25.46it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 26.69it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 17.92it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 31.82it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 36.00it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00, 19.19it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_nbr.to_pickle("neighborhoods.xz")

# %%
labels  = np.asarray(df_nbr["Label"])

# %%
phi_1 = [0,0]
phi_2 = np.pi/2
frequency = [0.1]
kf = KFold(n_splits=4)
base_fpr = np.linspace(0, 1, 100)
i = 0
for freq in frequency:
    for index,row in df_nbr.iterrows():
        nprow  = np.asarray(row["Features"]['[5, 5, 5]'])
        img = nprow.reshape(11,11,11)
        voxel = (np.subtract(img.shape, 1) / 2).astype(int)

        g = ndi.gaussian_filter(img, [1, 1, 0.3])
        g = np.asarray(float(g[[voxel[0]], [voxel[1]], [voxel[2]]]))

        gg = ndi.gaussian_gradient_magnitude(img, [1, 1, 0.3])
        gg = float(gg[[voxel[0]], [voxel[1]], [voxel[2]]])

        gl = ndi.gaussian_laplace(img, [1, 1, 0.3])
        gl = float(gl[[voxel[0]], [voxel[1]], [voxel[2]]])

        gb1 = gabor_filter(img, [1, 1, 0.3], phi_1, freq)[0]
        gb1 = float(gb1[[voxel[0]], [voxel[1]], [voxel[2]]])

        gb2 = gabor_filter(img, [1, 1, 0.3], phi_1, freq)[0]
        gb2 = float(gb2[[voxel[0]], [voxel[1]], [voxel[2]]])

        if index == 0:
            result = np.concatenate((nprow, g, gg, gl, gb1, gb2))
        else:
            result = np.vstack((result, np.concatenate((nprow, gb1.flatten(), gb2.flatten()))))

        preprocesser = preprocessing.StandardScaler().fit(result)
        lin_data = preprocesser.transform(result) 

        for train_index, test_index in kf.split(labels):
            X_train, X_test = lin_data[train_index,:], lin_data[test_index,:]
            y_train, y_test = labels[train_index], labels[test_index]

            clf = LogisticRegression(max_iter = 1000)
            clf.fit(X_train, y_train)
            predictions = clf.predict_proba(X_test)[:,1]
            inner_auc.append(metrics.roc_auc_score(y_test, predictions))

            temp_fpr, temp_tpr, _ = metrics.roc_curve(y_test, predictions)
            temp_tpr = interp(base_fpr, temp_fpr, temp_tpr)
            temp_tpr[0] = 0.0
            inner_tprs.append(temp_tpr)
        
        mid, high, low = compute_confidence(np.asarray(inner_tprs))
        if i == 0:
            final_auc = np.asarray(inner_auc)
            final_mid = np.asarray(mid)
            final_high = np.asarray(high)
            final_low = np.asarray(low)
        else:
            final_auc = np.vstack((final_auc, np.asarray(inner_auc)))
            final_mid = np.vstack((final_mid, np.asarray(mid)))
            final_high = np.vstack((final_high, np.asarray(high)))
            final_low = np.vstack((final_low, np.asarray(low)))

        i += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-87061d204864> in <module>
#      27
#      28         if index == 0:
# ---> 29             result = np.concatenate((nprow, g, gg, gl, gb1, gb2))
#      30         else:
#      31             result = np.vstack((result, np.concatenate((nprow, gb1.flatten(), gb2.flatten()))))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 0 dimension(s)

# %%
# Out:
# array([1., 0., 1., ..., 0., 1., 0.])
